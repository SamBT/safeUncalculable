# %%
from nnTrain import train_efn, train_pfn, arch_scan, get_data_softDrop
import matplotlib.pyplot as plt
import numpy as np
from multiprocessing import Process

# %% [markdown]
# # Quark jets, R = 0.8

# %%
# EFN
model_kwargs = {"Phi_sizes":(60,60,60), "F_sizes":(80,80,80),
                "input_dim":2,
                "output_dim":1,"output_act":"sigmoid",
                "loss":"binary_crossentropy",
                "summary":True}
train_kwargs = {"epochs":100,"verbose":1,"batch_size":10000}
efn, auc, efn_fp, efn_tp, threshs = train_efn("h2qq_R0.8_mH500_softDrop.h5",model_kwargs,train_kwargs,plot=True,sd=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# phats_input (InputLayer)        (None, None, 2)      0
# __________________________________________________________________________________________________
# tdist_0 (TimeDistributed)       (None, None, 60)     180         phats_input[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 60)     0           tdist_0[0][0]
# __________________________________________________________________________________________________
# tdist_1 (TimeDistributed)       (None, None, 60)     3660        activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, 60)     0           tdist_1[0][0]
# __________________________________________________________________________________________________
# zs_input (InputLayer)           (None, None)         0
# __________________________________________________________________________________________________
# tdist_2 (TimeDistributed)       (None, None, 60)     3660        activation_2[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           zs_input[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, 60)     0           tdist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 60)           0           mask[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 80)           4880        sum[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 80)           0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80)           6480        activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 80)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           6480        activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            81          activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 1)            0           output[0][0]
# ==================================================================================================
# Total params: 25,421
# Trainable params: 25,421
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 126041 samples, validate on 16805 samples
# Epoch 1/100
# 126041/126041 [==============================] - 4s 30us/step - loss: 0.6915 - acc: 0.5347 - val_loss: 0.6884 - val_acc: 0.5758
# Epoch 2/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.6841 - acc: 0.5758 - val_loss: 0.6771 - val_acc: 0.5877
# Epoch 3/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.6702 - acc: 0.5912 - val_loss: 0.6609 - val_acc: 0.6048
# Epoch 4/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.6541 - acc: 0.6122 - val_loss: 0.6444 - val_acc: 0.6334
# Epoch 5/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.6369 - acc: 0.6402 - val_loss: 0.6281 - val_acc: 0.6468
# Epoch 6/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.6206 - acc: 0.6557 - val_loss: 0.6128 - val_acc: 0.6599
# Epoch 7/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.6064 - acc: 0.6660 - val_loss: 0.5993 - val_acc: 0.6708
# Epoch 8/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5941 - acc: 0.6734 - val_loss: 0.5888 - val_acc: 0.6732
# Epoch 9/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5861 - acc: 0.6751 - val_loss: 0.5819 - val_acc: 0.6774
# Epoch 10/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5806 - acc: 0.6782 - val_loss: 0.5767 - val_acc: 0.6787
# Epoch 11/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5765 - acc: 0.6799 - val_loss: 0.5758 - val_acc: 0.6804
# Epoch 12/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5742 - acc: 0.6824 - val_loss: 0.5777 - val_acc: 0.6817
# Epoch 13/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5726 - acc: 0.6834 - val_loss: 0.5681 - val_acc: 0.6868
# Epoch 14/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5678 - acc: 0.6880 - val_loss: 0.5670 - val_acc: 0.6887
# Epoch 15/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5647 - acc: 0.6906 - val_loss: 0.5632 - val_acc: 0.6921
# Epoch 16/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.5621 - acc: 0.6939 - val_loss: 0.5601 - val_acc: 0.6957
# Epoch 17/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0
100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4531 - acc: 0.7810 - val_loss: 0.4584 - val_acc: 0.7780
# Epoch 84/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4536 - acc: 0.7819 - val_loss: 0.4581 - val_acc: 0.7780
# Epoch 85/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4511 - acc: 0.7826 - val_loss: 0.4561 - val_acc: 0.7782
# Epoch 86/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4502 - acc: 0.7838 - val_loss: 0.4578 - val_acc: 0.7782
# Epoch 87/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4509 - acc: 0.7841 - val_loss: 0.4591 - val_acc: 0.7789
# Epoch 88/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4476 - acc: 0.7858 - val_loss: 0.4546 - val_acc: 0.7775
# Epoch 89/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4462 - acc: 0.7863 - val_loss: 0.4536 - val_acc: 0.7785
# Epoch 90/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4456 - acc: 0.7867 - val_loss: 0.4529 - val_acc: 0.7802
# Epoch 91/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4457 - acc: 0.7864 - val_loss: 0.4522 - val_acc: 0.7822
# Epoch 92/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4449 - acc: 0.7877 - val_loss: 0.4554 - val_acc: 0.7780
# Epoch 93/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4432 - acc: 0.7888 - val_loss: 0.4504 - val_acc: 0.7828
# Epoch 94/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4416 - acc: 0.7904 - val_loss: 0.4499 - val_acc: 0.7810
# Epoch 95/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4412 - acc: 0.7901 - val_loss: 0.4497 - val_acc: 0.7853
# Epoch 96/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4404 - acc: 0.7903 - val_loss: 0.4483 - val_acc: 0.7836
# Epoch 97/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4402 - acc: 0.7907 - val_loss: 0.4456 - val_acc: 0.7838
# Epoch 98/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4400 - acc: 0.7912 - val_loss: 0.4474 - val_acc: 0.7810
# Epoch 99/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4396 - acc: 0.7907 - val_loss: 0.4452 - val_acc: 0.7846
# Epoch 100/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.4358 - acc: 0.7935 - val_loss: 0.4442 - val_acc: 0.7873
# EFN AUC: 0.873903310896755

# %%
X,Y = get_data_softDrop("h2qq_R0.8_mH500_softDrop.h5")
z = X[:,:,0]
p = X[:,:,1:]
preds = efn.predict([z, p], batch_size=1000)
preds = preds[:,0]

plt.figure(figsize=(10,8))
pred_parton = preds[Y==0]
pred_hadron = preds[Y==1]
bins = np.arange(0,1.01,0.01)
hp = plt.hist(pred_parton,bins=bins,histtype='step',label="Parton-Level Jets")
hh = plt.hist(pred_hadron,bins=bins,histtype='step',label="Hadron-Level Jets")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("EFN Score",fontsize=16)
plt.legend(loc='upper left',fontsize=16)
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.savefig("EFN_scores_PartonVsHadron_qJets.pdf")

ratio = np.where(hh[0]>0,hp[0]/hh[0],np.zeros_like(hp[0]))
plt.figure(figsize=(10,8))
bin_centers = (bins[:-1]+bins[1:])/2
bin_width = bins[1]-bins[0]
plt.hist(bin_centers,weights=ratio,bins=bins,histtype='step')
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("EFN Score",fontsize=16)
plt.ylabel(r"$N_{parton} / N_{hadron}$",fontsize=16)
plt.savefig("EFN_PartonHadronRatio_qJets.pdf")
# Out:
# /home/sambt/.conda/envs/sambt-uproot/lib/python3.6/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide

# %%
# PFN
model_kwargs = {"Phi_sizes":(60,60,60), "F_sizes":(80,80,80),
                "input_dim":3,
                "output_dim":1,"output_act":"sigmoid",
                "loss":"binary_crossentropy",
                "summary":True}
train_kwargs = {"epochs":100,"verbose":1,"batch_size":10000}
pfn, auc, pfn_fp, pfn_tp, threshs = train_pfn("h2qq_R0.8_mH500_softDrop.h5",model_kwargs,train_kwargs,plot=True,sd=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, None, 3)      0
# __________________________________________________________________________________________________
# tdist_0 (TimeDistributed)       (None, None, 60)     240         input[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, 60)     0           tdist_0[0][0]
# __________________________________________________________________________________________________
# tdist_1 (TimeDistributed)       (None, None, 60)     3660        activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, 60)     0           tdist_1[0][0]
# __________________________________________________________________________________________________
# tdist_2 (TimeDistributed)       (None, None, 60)     3660        activation_9[0][0]
# __________________________________________________________________________________________________
# mask (Lambda)                   (None, None)         0           input[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, 60)     0           tdist_2[0][0]
# __________________________________________________________________________________________________
# sum (Dot)                       (None, 60)           0           mask[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# dense_0 (Dense)                 (None, 80)           4880        sum[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 80)           0           dense_0[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80)           6480        activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 80)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80)           6480        activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 80)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            81          activation_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 1)            0           output[0][0]
# ==================================================================================================
# Total params: 25,481
# Trainable params: 25,481
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 126041 samples, validate on 16805 samples
# Epoch 1/100
# 126041/126041 [==============================] - 4s 33us/step - loss: 0.6124 - acc: 0.6251 - val_loss: 0.4695 - val_acc: 0.8060
# Epoch 2/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.3828 - acc: 0.8487 - val_loss: 0.2878 - val_acc: 0.8854
# Epoch 3/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.2274 - acc: 0.9096 - val_loss: 0.1809 - val_acc: 0.9311
# Epoch 4/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1583 - acc: 0.9378 - val_loss: 0.1459 - val_acc: 0.9443
# Epoch 5/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1262 - acc: 0.9525 - val_loss: 0.1200 - val_acc: 0.9570
# Epoch 6/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1122 - acc: 0.9596 - val_loss: 0.1127 - val_acc: 0.9596
# Epoch 7/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1119 - acc: 0.9599 - val_loss: 0.1077 - val_acc: 0.9626
# Epoch 8/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1036 - acc: 0.9630 - val_loss: 0.1077 - val_acc: 0.9621
# Epoch 9/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1015 - acc: 0.9641 - val_loss: 0.1054 - val_acc: 0.9638
# Epoch 10/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.1005 - acc: 0.9643 - val_loss: 0.1043 - val_acc: 0.9650
# Epoch 11/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0994 - acc: 0.9651 - val_loss: 0.1037 - val_acc: 0.9654
# Epoch 12/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0981 - acc: 0.9656 - val_loss: 0.1042 - val_acc: 0.9634
# Epoch 13/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0973 - acc: 0.9659 - val_loss: 0.1026 - val_acc: 0.9655
# Epoch 14/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0969 - acc: 0.9658 - val_loss: 0.1133 - val_acc: 0.9598
# Epoch 15/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0981 - acc: 0.9656 - val_loss: 0.1004 - val_acc: 0.9654
# Epoch 16/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0971 - acc: 0.9660 - val_loss: 0.1018 - val_acc: 0.9655
# Epoch 17/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0959 - acc: 0.9662 - val_loss: 0.1021 - val_acc: 0.9647
# Epoch 18/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0944 - acc: 0.9668 - val_loss: 0.1000 - val_acc: 0.9657
# Epoch 19/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.
100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0832 - acc: 0.9707 - val_loss: 0.0887 - val_acc: 0.9698
# Epoch 87/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0841 - acc: 0.9704 - val_loss: 0.0899 - val_acc: 0.9695
# Epoch 88/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0831 - acc: 0.9704 - val_loss: 0.0887 - val_acc: 0.9698
# Epoch 89/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0823 - acc: 0.9712 - val_loss: 0.0894 - val_acc: 0.9697
# Epoch 90/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0830 - acc: 0.9709 - val_loss: 0.0886 - val_acc: 0.9703
# Epoch 91/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0830 - acc: 0.9709 - val_loss: 0.0935 - val_acc: 0.9680
# Epoch 92/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0847 - acc: 0.9703 - val_loss: 0.0950 - val_acc: 0.9670
# Epoch 93/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0860 - acc: 0.9697 - val_loss: 0.0898 - val_acc: 0.9695
# Epoch 94/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0844 - acc: 0.9700 - val_loss: 0.0907 - val_acc: 0.9693
# Epoch 95/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0827 - acc: 0.9709 - val_loss: 0.0895 - val_acc: 0.9697
# Epoch 96/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0826 - acc: 0.9709 - val_loss: 0.0881 - val_acc: 0.9701
# Epoch 97/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0824 - acc: 0.9712 - val_loss: 0.0887 - val_acc: 0.9699
# Epoch 98/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0820 - acc: 0.9713 - val_loss: 0.0883 - val_acc: 0.9697
# Epoch 99/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0832 - acc: 0.9705 - val_loss: 0.0925 - val_acc: 0.9682
# Epoch 100/100
# 126041/126041 [==============================] - 1s 8us/step - loss: 0.0826 - acc: 0.9708 - val_loss: 0.0898 - val_acc: 0.9695
# PFN AUC: 0.9936297565545189

# %%
X,Y = get_data_softDrop("h2qq_R0.8_mH500_softDrop.h5")
preds = pfn.predict(X, batch_size=1000)
preds = preds[:,0]

plt.figure(figsize=(10,8))
pred_parton = preds[Y==0]
pred_hadron = preds[Y==1]
bins = np.arange(0,1.01,0.01)
hp = plt.hist(pred_parton,bins=bins,histtype='step',label="Parton-Level Jets")
hh = plt.hist(pred_hadron,bins=bins,histtype='step',label="Hadron-Level Jets")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("PFN Score",fontsize=16)
plt.legend(loc='upper left',fontsize=16)
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.savefig("PFN_scores_PartonVsHadron_qJets.pdf")

ratio = np.where(hh[0]>0,hp[0]/hh[0],np.zeros_like(hp[0]))
plt.figure(figsize=(10,8))
bin_centers = (bins[:-1]+bins[1:])/2
bin_width = bins[1]-bins[0]
plt.hist(bin_centers,weights=ratio,bins=bins,histtype='step')
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("pfn Score",fontsize=16)
plt.ylabel(r"$N_{parton} / N_{hadron}$",fontsize=16)
plt.savefig("PFN_PartonHadronRatio_qJets.pdf")

# %% [markdown]
# # Gluon Jets, R = 0.8

# %%
# EFN
model_kwargs = {"Phi_sizes":(60,60,60), "F_sizes":(80,80,80),
                "input_dim":2,
                "output_dim":1,"output_act":"sigmoid",
                "loss":"binary_crossentropy",
                "summary":True}
train_kwargs = {"epochs":100,"verbose":1,"batch_size":10000}
efn, auc, efn_fp, efn_tp, threshs = train_efn("h2gg_R0.8_mH500_softDrop.h5",model_kwargs,train_kwargs,plot=True,sd=True)

# %%
X,Y = get_data_softDrop("h2gg_R0.8_mH500_softDrop.h5")
z = X[:,:,0]
p = X[:,:,1:]
preds = efn.predict([z, p], batch_size=1000)
preds = preds[:,0]

plt.figure(figsize=(10,8))
pred_parton = preds[Y==0]
pred_hadron = preds[Y==1]
bins = np.arange(0,1.01,0.01)
hp = plt.hist(pred_parton,bins=bins,histtype='step',label="Parton-Level Jets")
hh = plt.hist(pred_hadron,bins=bins,histtype='step',label="Hadron-Level Jets")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("EFN Score",fontsize=16)
plt.legend(loc='upper left',fontsize=16)
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.savefig("EFN_scores_PartonVsHadron_gJets.pdf")

ratio = np.where(hh[0]>0,hp[0]/hh[0],np.zeros_like(hp[0]))
plt.figure(figsize=(10,8))
bin_centers = (bins[:-1]+bins[1:])/2
bin_width = bins[1]-bins[0]
plt.hist(bin_centers,weights=ratio,bins=bins,histtype='step')
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("EFN Score",fontsize=16)
plt.ylabel(r"$N_{parton} / N_{hadron}$",fontsize=16)
plt.savefig("EFN_PartonHadronRatio_gJets.pdf")

# %%
# PFN
model_kwargs = {"Phi_sizes":(60,60,60), "F_sizes":(80,80,80),
                "input_dim":3,
                "output_dim":1,"output_act":"sigmoid",
                "loss":"binary_crossentropy",
                "summary":True}
train_kwargs = {"epochs":100,"verbose":1,"batch_size":10000}
pfn, auc, pfn_fp, pfn_tp, threshs = train_pfn("h2gg_R0.8_mH500_softDrop.h5",model_kwargs,train_kwargs,plot=True,sd=True)

# %%
X,Y = get_data_softDrop("h2gg_R0.8_mH500_softDrop.h5")
preds = pfn.predict(X, batch_size=1000)
preds = preds[:,0]

plt.figure(figsize=(10,8))
pred_parton = preds[Y==0]
pred_hadron = preds[Y==1]
bins = np.arange(0,1.01,0.01)
hp = plt.hist(pred_parton,bins=bins,histtype='step',label="Parton-Level Jets")
hh = plt.hist(pred_hadron,bins=bins,histtype='step',label="Hadron-Level Jets")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("PFN Score",fontsize=16)
plt.legend(loc='upper left',fontsize=16)
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.savefig("PFN_scores_PartonVsHadron_gJets.pdf")

ratio = np.where(hh[0]>0,hp[0]/hh[0],np.zeros_like(hp[0]))
plt.figure(figsize=(10,8))
bin_centers = (bins[:-1]+bins[1:])/2
bin_width = bins[1]-bins[0]
plt.hist(bin_centers,weights=ratio,bins=bins,histtype='step')
plt.title(r"$\Phi = $ NN(60,60,60), $F = $ NN(80,80,80), $n_{epoch} = 10$",fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("pfn Score",fontsize=16)
plt.ylabel(r"$N_{parton} / N_{hadron}$",fontsize=16)
plt.savefig("PFN_PartonHadronRatio_gJets.pdf")
