# %%
# %load_ext autoreload
# %autoreload 2
from evtGen import generate_eeH, generate_eeH_withSD
import numpy as np

# %%
generate_eeH_withSD("q",100000,"h2qq")
# Out:
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.307      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Feb 2022  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 24 Jan 2023 at 11:48:54    |  |
#  |  |                                                                              |  |
# ...

# %%
generate_eeH_withSD("g",100000,"h2gg")
# Out:
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.307      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Feb 2022  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 24 Jan 2023 at 11:52:14    |  |
#  |  |                                                                              |  |
# ...
