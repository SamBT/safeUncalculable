# %%
# %load_ext autoreload
# %autoreload 2
from evtGen import generate_eeH, generate_eeH_withSD
import numpy as np
import h5py

# %%
generate_eeH("g",100000,"h2gg_set9")
# Out:
# starting?
#
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.307      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Feb 2022  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 09 Jul 2023 at 20:55:10    |  |
# ...

# %%
generate_eeH("q",100000,"h2qq_set10")
# Out:
#  *------------------------------------------------------------------------------------*
#  |                                                                                    |
#  |  *------------------------------------------------------------------------------*  |
#  |  |                                                                              |  |
#  |  |                                                                              |  |
#  |  |   PPP   Y   Y  TTTTT  H   H  III    A      Welcome to the Lund Monte Carlo!  |  |
#  |  |   P  P   Y Y     T    H   H   I    A A     This is PYTHIA version 8.307      |  |
#  |  |   PPP     Y      T    HHHHH   I   AAAAA    Last date of change: 25 Feb 2022  |  |
#  |  |   P       Y      T    H   H   I   A   A                                      |  |
#  |  |   P       Y      T    H   H  III  A   A    Now is 07 Jul 2023 at 18:47:44    |  |
#  |  |                                                                              |  |
# ...

# %% [markdown]
# # Merge Files

# %%
import os
import h5py

base = "/uscms/home/sbrightt/nobackup/jets-ml/datasets/safeIncalculable/"
gjets = [f for f in os.listdir(base) if "h2gg_set" in f and ".h5" in f]
qjets = [f for f in os.listdir(base) if "h2gg_set" in f and ".h5" in f]
